# %% [markdown]
# <a href="https://colab.research.google.com/github/leman-cap13/kaggle_datasets_/blob/main/TurboAz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# !kaggle datasets download sehriyarmemmedli/turboaz-cars-project
# Out:
# Dataset URL: https://www.kaggle.com/datasets/sehriyarmemmedli/turboaz-cars-project
# License(s): unknown
# ...
#  98% 235M/240M [00:03<00:00, 43.1MB/s]
# 100% 240M/240M [00:04<00:00, 62.5MB/s]

# %%
# !unzip turboaz-cars-project.zip
# Out:
# Archive:  turboaz-cars-project.zip
#   inflating: cars.csv

# %%
df=pd.read_csv('/content/turboaz-cars-project.zip')

# %%
pd.set_option('display.max_columns', None)

# %%
df.head(1)
# Out:
#                                    id_x               car_rel_url_x  \
# 0  3c234145-d57a-4ad6-9448-d43810fc3392  /autos/8748840-hyundai-i30
#
#                  datetime_scrape         name  price_x currency_x  \
# 0  2024-09-13 20:32:19.751157+00  Hyundai i30  15000.0        AZN
#
#     datetime_product  city         day   hour               attributes  \
# 0  Bakı, dünən 23:28  bakı  13.09.2024  23:28  2008, 1.6 L, 270 000 km
#
#    production_year  engine_displacement_num engine_displacement_unit  \
# 0             2008                      1.6                        L
#
#    kilometrage_num kilometrage_unit barter loan salon spare_parts  vip  \
# 0           270000               km    NaN  NaN   NaN         NaN  NaN
#
#   featured                                            img_url  \
# 0      NaN  https://turbo.azstatic.com/uploads/f460x343/20...
#
#                                    id_y                               cars_id  \
# ...

# %%
df.columns
# Out:
# Index(['id_x', 'car_rel_url_x', 'datetime_scrape', 'name', 'price_x',
#        'currency_x', 'datetime_product', 'city', 'day', 'hour', 'attributes',
#        'production_year', 'engine_displacement_num',
#        'engine_displacement_unit', 'kilometrage_num', 'kilometrage_unit',
#        'barter', 'loan', 'salon', 'spare_parts', 'vip', 'featured', 'img_url',
#        'id_y', 'cars_id', 'car_rel_url_y', 'datetime', 'description',
#        'price_y', 'currency_y', 'owner_name', 'shop_name', 'phone', 'updated',
#        'views', 'vin', 'car_details_id_x', 'Ban növü', 'Buraxılış ili',
#        'Hansı bazar üçün yığılıb', 'Marka', 'Model', 'Mühərrik', 'Qəzalı',
#        'Rəng', 'Sahiblər', 'Sürətlər qutusu', 'Vəziyyəti', 'Yeni',
#        'Yerlərin sayı', 'Yürüş', 'Ötürücü', 'Şəhər', 'car_details_id_y',
#        'car_rel_url', 'extra_info'],
#       dtype='object')

# %%
df=df.drop(['id_x','car_rel_url_x','datetime_scrape','datetime_product','img_url','id_y','cars_id','car_rel_url_y','car_details_id_x',
         'car_details_id_y','car_rel_url','price_y','currency_y','name','views','datetime'],axis=1)
df
# Out:
#          price_x currency_x      city         day   hour  \
# 0        15000.0        AZN      bakı  13.09.2024  23:28
# 1        23700.0        AZN      bakı  13.09.2024  23:59
# 2        35600.0          $      bakı  13.09.2024  23:59
# 3        26700.0        AZN      bakı  13.09.2024  23:59
# 4        10500.0        AZN      bakı  13.09.2024  23:59
# ...          ...        ...       ...         ...    ...
# 653716   10800.0        AZN      bakı  05.01.2025  00:03
# 653717    9500.0        AZN    göygöl  05.01.2025  00:32
# 653718   25400.0        AZN      bakı  05.01.2025  00:00
# 653719   10600.0        AZN  kürdəmir  05.01.2025  09:02
# 653720  128500.0          $      bakı  05.01.2025  00:09
#
#                      attributes  production_year  engine_displacement_num  \
# 0       2008, 1.6 L, 270 000 km             2008                      1.6
# 1             2024, 1.7 L, 0 km             2024                      1.7
# ...

# %%
df.columns
# Out:
# Index(['price_x', 'currency_x', 'city', 'day', 'hour', 'attributes',
#        'production_year', 'engine_displacement_num',
#        'engine_displacement_unit', 'kilometrage_num', 'kilometrage_unit',
#        'barter', 'loan', 'salon', 'spare_parts', 'vip', 'featured',
#        'description', 'owner_name', 'shop_name', 'phone', 'updated', 'vin',
#        'Ban növü', 'Buraxılış ili', 'Hansı bazar üçün yığılıb', 'Marka',
#        'Model', 'Mühərrik', 'Qəzalı', 'Rəng', 'Sahiblər', 'Sürətlər qutusu',
#        'Vəziyyəti', 'Yeni', 'Yerlərin sayı', 'Yürüş', 'Ötürücü', 'Şəhər',
#        'extra_info'],
#       dtype='object')

# %%
df=df.rename(columns={'price_x':'Price', 'currency_x':'Currency'})
df
# Out:
#            Price Currency      city         day   hour  \
# 0        15000.0      AZN      bakı  13.09.2024  23:28
# 1        23700.0      AZN      bakı  13.09.2024  23:59
# 2        35600.0        $      bakı  13.09.2024  23:59
# 3        26700.0      AZN      bakı  13.09.2024  23:59
# 4        10500.0      AZN      bakı  13.09.2024  23:59
# ...          ...      ...       ...         ...    ...
# 653716   10800.0      AZN      bakı  05.01.2025  00:03
# 653717    9500.0      AZN    göygöl  05.01.2025  00:32
# 653718   25400.0      AZN      bakı  05.01.2025  00:00
# 653719   10600.0      AZN  kürdəmir  05.01.2025  09:02
# 653720  128500.0        $      bakı  05.01.2025  00:09
#
#                      attributes  production_year  engine_displacement_num  \
# 0       2008, 1.6 L, 270 000 km             2008                      1.6
# 1             2024, 1.7 L, 0 km             2024                      1.7
# 2       2011, 4.0 L, 164 750 km             2011                      4.0
# ...

# %%
df.dtypes
# Out:
# Price                       float64
# Currency                     object
# city                         object
# day                          object
# hour                         object
# attributes                   object
# production_year               int64
# engine_displacement_num     float64
# engine_displacement_unit     object
# kilometrage_num               int64
# kilometrage_unit             object
# barter                       object
# loan                         object
# salon                        object
# spare_parts                  object
# vip                          object
# featured                     object
# description                  object
# owner_name                   object
# shop_name                    object
# phone                       float64
# updated                      object
# vin                          object
# Ban növü                     object
# Buraxılış ili                 int64
# Hansı bazar üçün yığılıb     object
# ...

# %%
# df['Price']=df['Price'].astype('int')

# %%
# df['Price'].dtype

# %%
df['Currency'].nunique()
# Out:
# 3

# %%
df['Currency'].unique()
# Out:
# array(['AZN', '$', '€'], dtype=object)

# %%
df.loc[df['Currency'] == '$', 'Price'] = df.loc[df['Currency'] == '$', 'Price'] * 1.7

# %%
df['Price'].head()
# Out:
# 0    15000.0
# 1    23700.0
# 2    60520.0
# 3    26700.0
# 4    10500.0
# Name: Price, dtype: float64

# %%
df[df['Currency']=='$']=df[df['Currency']=='$'].replace('$','AZN')

# %%
df[['Price','Currency']]
# Out:
#            Price Currency
# 0        15000.0      AZN
# 1        23700.0      AZN
# 2        60520.0      AZN
# 3        26700.0      AZN
# 4        10500.0      AZN
# ...          ...      ...
# 653716   10800.0      AZN
# 653717    9500.0      AZN
# 653718   25400.0      AZN
# 653719   10600.0      AZN
# 653720  218450.0      AZN
#
# [653721 rows x 2 columns]

# %%
df['Currency'].value_counts()
# Out:
# Currency
# AZN    647834
# €        5887
# Name: count, dtype: int64

# %%
df[df['Currency'] == '€']
# Out:
#            Price Currency  city         day   hour              attributes  \
# 88      180000.0        €  bakı  13.09.2024  23:24       2024, 3.0 L, 0 km
# 486      88000.0        €  bakı  13.09.2024  21:36       2023, 3.0 L, 0 km
# 957     118000.0        €  bakı  13.09.2024  20:01  2023, 0.0 L, 16 000 km
# 1623    132183.0        €  bakı  13.09.2024  18:18       2024, 3.0 L, 0 km
# 1881    142000.0        €  bakı  13.09.2024  17:41       2023, 0.0 L, 0 km
# ...          ...      ...   ...         ...    ...                     ...
# 653184   79900.0        €  bakı  05.01.2025  09:42       2024, 2.0 L, 0 km
# 653185   65500.0        €  bakı  05.01.2025  09:41       2024, 2.0 L, 0 km
# 653186  215000.0        €  bakı  05.01.2025  09:41       2024, 3.0 L, 0 km
# 653195  128500.0        €  bakı  05.01.2025  09:40       2024, 3.0 L, 0 km
# 653197   86500.0        €  bakı  05.01.2025  09:40       2024, 2.0 L, 0 km
#
# ...

# %%
df.loc[df['Currency'] == '€', 'Price'] = df.loc[df['Currency'] == '€', 'Price'] * 1.75
df
# Out:
#            Price Currency      city         day   hour  \
# 0        15000.0      AZN      bakı  13.09.2024  23:28
# 1        23700.0      AZN      bakı  13.09.2024  23:59
# 2        60520.0      AZN      bakı  13.09.2024  23:59
# 3        26700.0      AZN      bakı  13.09.2024  23:59
# 4        10500.0      AZN      bakı  13.09.2024  23:59
# ...          ...      ...       ...         ...    ...
# 653716   10800.0      AZN      bakı  05.01.2025  00:03
# 653717    9500.0      AZN    göygöl  05.01.2025  00:32
# 653718   25400.0      AZN      bakı  05.01.2025  00:00
# 653719   10600.0      AZN  kürdəmir  05.01.2025  09:02
# 653720  218450.0      AZN      bakı  05.01.2025  00:09
#
#                      attributes  production_year  engine_displacement_num  \
# 0       2008, 1.6 L, 270 000 km             2008                      1.6
# 1             2024, 1.7 L, 0 km             2024                      1.7
# 2       2011, 4.0 L, 164 750 km             2011                      4.0
# ...

# %%
df[df['Currency']=='€']=df[df['Currency']=='€'].replace('€','AZN')
# Out:
# <ipython-input-23-1ab5e3ec0ff3>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[df['Currency']=='€']=df[df['Currency']=='€'].replace('€','AZN')

# %%
df['Currency'].nunique()
# Out:
# 1

# %%
df=df.drop(['Currency','attributes','owner_name','phone','Şəhər','description','extra_info'], axis=1)

# %%
df[['day','updated']]
# Out:
#                day     updated
# 0       13.09.2024  13.09.2024
# 1       13.09.2024  13.09.2024
# 2       13.09.2024  13.09.2024
# 3       13.09.2024  13.09.2024
# 4       13.09.2024  13.09.2024
# ...            ...         ...
# 653716  05.01.2025  05.01.2025
# 653717  05.01.2025  05.01.2025
# 653718  05.01.2025  05.01.2025
# 653719  05.01.2025  05.01.2025
# 653720  05.01.2025  05.01.2025
#
# [653721 rows x 2 columns]

# %%
# df['day_equals_updated'] = df['day'] == df['updated']
# df['day_equals_updated'].unique()

# %%
df['Price']=df['Price'].astype('int')

# %%
df['Ban növü'] = df['Ban növü'].str.split(r'[/,]').str[0]

# %%
df['Ban növü'].unique()
# Out:
# array(['Hetçbek', 'Offroader ', 'Sedan', 'Liftbek', 'Yük maşını',
#        'Kompakt-Van', 'Furqon', 'Minivan', 'Mikroavtobus', 'Universal',
#        'Motosiklet', 'SUV Kupe', 'Kupe', 'Pikap', 'Dartqı', 'Kabriolet',
#        'Kvadrosikl', 'Limuzin', 'Avtobus', 'Rodster', 'Moped', 'Karvan',
#        'Van', 'Mikrovan', 'Tarqa', 'Fastbek', 'Fayton', 'Spidster',
#        'Qolfkar'], dtype=object)

# %%
df['Mühərrik_part2']=df['Mühərrik'].copy().str.split('/').str[1]

# %%
df['Mühərrik_part2']
# Out:
# 0           115 a.g.
# 1            80 a.g.
# 2           282 a.g.
# 3           150 a.g.
# 4            76 a.g.
#              ...
# 653716      76 a.g.
# 653717     135 a.g.
# 653718     150 a.g.
# 653719     258 a.g.
# 653720     400 a.g.
# Name: Mühərrik_part2, Length: 653721, dtype: object

# %%
df['Mühərrik_part3']=df['Mühərrik'].copy().str.split('/').str[2]

# %%
df['Mühərrik_part3']
# Out:
# 0           Dizel
# 1          Benzin
# 2          Benzin
# 3          Benzin
# 4          Hibrid
#            ...
# 653716     Hibrid
# 653717     Benzin
# 653718     Benzin
# 653719     Benzin
# 653720     Benzin
# Name: Mühərrik_part3, Length: 653721, dtype: object

# %% [markdown]
# .str.extract(r'(\d+)') extract numbers from string

# %%
df['Mühərrik_part2']=df['Mühərrik_part2'].str.extract(r'(\d+)')
df['Mühərrik_part2']
# Out:
# 0         115
# 1          80
# 2         282
# 3         150
# 4          76
#          ...
# 653716     76
# 653717    135
# 653718    150
# 653719    258
# 653720    400
# Name: Mühərrik_part2, Length: 653721, dtype: object

# %%
df[~df['Mühərrik_part2'].isna()]['Mühərrik_part2'].astype(int).median()
# Out:
# 181.0

# %%
df['Mühərrik_part2'] = df['Mühərrik_part2'].fillna('0')

# %%
df['Mühərrik_part2'].isna().sum()
# Out:
# 0

# %%
df['Mühərrik_part2'] = df['Mühərrik_part2'].astype(int)

# %%
df['Mühərrik_part2'].fillna(df['Mühərrik_part2'].median())
# Out:
# 0         115
# 1          80
# 2         282
# 3         150
# 4          76
#          ...
# 653716     76
# 653717    135
# 653718    150
# 653719    258
# 653720    400
# Name: Mühərrik_part2, Length: 653721, dtype: int64

# %%
df['kilometrage_unit'].nunique()
# Out:
# 1

# %%
df=df.drop('kilometrage_unit',axis=1)

# %%
df['Sahiblər'].unique()
# Out:
# array(['2', nan, '0', '1', '3', '4 və daha çox'], dtype=object)

# %%
df['Sahiblər'].value_counts()
# Out:
# Sahiblər
# 1                207016
# 2                128779
# 0                 75150
# 3                 17966
# 4 və daha çox      3189
# Name: count, dtype: int64

# %%
df['Sahiblər']=df['Sahiblər'].str.replace('4 və daha çox','4')
df['Sahiblər']
# Out:
# 0           2
# 1         NaN
# 2           0
# 3           1
# 4           2
#          ...
# 653716      2
# 653717      0
# 653718      0
# 653719      2
# 653720      0
# Name: Sahiblər, Length: 653721, dtype: object

# %%
df['Sahiblər'].value_counts()
# Out:
# Sahiblər
# 1    207016
# 2    128779
# 0     75150
# 3     17966
# 4      3189
# Name: count, dtype: int64

# %%
df['Sahiblər']=df['Sahiblər'].fillna(df[~df['Sahiblər'].isna()]['Sahiblər'].astype(int).median())

# %%
df['Sahiblər'].value_counts()
# Out:
# Sahiblər
# 1.0    221621
# 1      207016
# 2      128779
# 0       75150
# 3       17966
# 4        3189
# Name: count, dtype: int64

# %%
df['Sahiblər']=df['Sahiblər'].astype('int')

# %%
df['Yerlərin sayı'].unique()
# Out:
# array(['5', '8+', nan, '3', '7', '2', '4', '6', '1'], dtype=object)

# %%
df['Yerlərin sayı']=df['Yerlərin sayı'].replace('8+','8')

# %%
df['Yerlərin sayı']=df['Yerlərin sayı'].fillna(df[~df['Yerlərin sayı'].isna()]['Yerlərin sayı'].astype(int).median())
df['Yerlərin sayı']
# Out:
# 0           5
# 1           5
# 2           8
# 3         5.0
# 4           5
#          ...
# 653716      5
# 653717    5.0
# 653718      5
# 653719      5
# 653720      5
# Name: Yerlərin sayı, Length: 653721, dtype: object

# %%
df['Yerlərin sayı']=df['Yerlərin sayı'].astype('int')

# %%
df['day'].dtype
# Out:
# dtype('O')

# %%
df['Yürüş']=df['Yürüş'].str.extract(r'(\d+)')

# %%
df['Yürüş']=df['Yürüş'].astype('int')
df['Yürüş']
# Out:
# 0         270
# 1           0
# 2         164
# 3         126
# 4         354
#          ...
# 653716    320
# 653717    155
# 653718     77
# 653719    250
# 653720     19
# Name: Yürüş, Length: 653721, dtype: int64

# %%
df.isna().sum()
# Out:
# Price                            0
# city                             0
# day                              0
# hour                             0
# production_year                  0
# engine_displacement_num          0
# engine_displacement_unit      5788
# kilometrage_num                  0
# barter                      428168
# loan                        490381
# salon                       460382
# spare_parts                 651959
# vip                         364780
# featured                    489886
# shop_name                   453761
# updated                          0
# vin                         609450
# Ban növü                         0
# Buraxılış ili                    0
# Hansı bazar üçün yığılıb    189505
# Marka                            0
# Model                            1
# Mühərrik                         0
# Qəzalı                      651960
# Rəng                             0
# Sahiblər                         0
# Sürətlər qutusu                  0
# ...

# %%
df=df.drop('Mühərrik',axis=1)

# %%
df['barter'].unique()
# Out:
# array([nan, 'Barter mümkündür'], dtype=object)

# %%
df['barter']=df['barter'].fillna('Barter mümkün deyil')

# %%
df['barter'].unique()
# Out:
# array(['Barter mümkün deyil', 'Barter mümkündür'], dtype=object)

# %%
df['loan'].unique()
# Out:
# array([nan, 'Kreditdədir'], dtype=object)

# %%
df['loan']=df['loan'].fillna('Kreditde deyil')

# %%
df['loan'].unique()
# Out:
# array(['Kreditde deyil', 'Kreditdədir'], dtype=object)

# %%
df['salon'].unique()
# Out:
# array([nan, 'Salon'], dtype=object)

# %%
df['salon']=df['salon'].fillna('Salon yox')

# %%
df['salon'].unique()
# Out:
# array(['Salon yox', 'Salon'], dtype=object)

# %%
df['spare_parts'].unique()
# Out:
# array([nan, 'Qəzalı'], dtype=object)

# %%
df['spare_parts']=df['spare_parts'].fillna('Qezasiz')

# %%
df['spare_parts'].unique()
# Out:
# array(['Qezasiz', 'Qəzalı'], dtype=object)

# %%
df['vip'].unique()
# Out:
# array([nan, 'vipped-icon'], dtype=object)

# %%
df['vip']=df['vip'].fillna('vipped-icon deyil')

# %%
df['vip'].unique()
# Out:
# array(['vipped-icon deyil', 'vipped-icon'], dtype=object)

# %%
df['featured'].unique()
# Out:
# array([nan, 'featured-icon'], dtype=object)

# %%
df['featured']=df['featured'].fillna('featured-icon deyil')

# %%
df['featured'].unique()
# Out:
# array(['featured-icon deyil', 'featured-icon'], dtype=object)

# %%
df['vin'].unique()
# Out:
# array([nan, '5NPD84LFXKH406133', 'WDB2020201F729708', ...,
#        '1G1PC5SB2F7265559', '5TDDBRCH4MS528872', 'KMHNU81WP9U098497'],
#       dtype=object)

# %%
df['vin'].isna().sum()
# Out:
# 609450

# %%
df['vin']=df['vin'].replace('...','unknow')
df['vin']
# Out:
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3         5NPD84LFXKH406133
# 4                       NaN
#                 ...
# 653716                  NaN
# 653717                  NaN
# 653718    5NPD84LF9JH337806
# 653719                  NaN
# 653720                  NaN
# Name: vin, Length: 653721, dtype: object

# %%
df['Qəzalı'].unique()
# Out:
# array([nan, 'Bəli'], dtype=object)

# %%
df['Qəzalı']=df['Qəzalı'].fillna('Xeyr')

# %%
df['Qəzalı'].unique()
# Out:
# array(['Xeyr', 'Bəli'], dtype=object)

# %%
df['Hansı bazar üçün yığılıb'].unique()
# Out:
# array([nan, 'Rəsmi diler', 'Amerika', 'Dubay', 'Rusiya', 'Çin', 'Avropa',
#        'Digər', 'Yaponiya', 'Koreya'], dtype=object)

# %%
df['Marka'] = df['Marka'].str.replace(r'\(.*?\)', '', regex=True)

# %%
df['Marka'].unique()
# Out:
# array(['Hyundai', 'LADA ', 'Toyota', 'BMW', 'Mercedes', 'Skoda', 'Kia',
#        'Geely', 'Ford', 'Daewoo', 'Opel', 'Land Rover', 'Chevrolet',
#        'Nissan', 'Mazda', 'Fiat', 'Jeep', 'RAF', 'SEAT', 'C.Moto', 'UAZ',
#        'Volkswagen', 'Lexus', 'Audi', 'Mitsubishi', 'Bentley', 'Honda',
#        'Porsche', 'Cadillac', 'FAW', 'Renault', 'GAZ', 'Mini', 'Maserati',
#        'BYD', 'Mercedes-Maybach', 'Lincoln', 'Chrysler', 'Khazar',
#        'Tufan', 'GMC', 'Changan', 'Tesla', 'Saipa', 'DFSK', 'Scania',
#        'Jaguar', 'DAF', 'Infiniti', 'Iran Khodro', 'ZEEKR', 'iCar',
#        'Tofas', 'Subaru', 'Chery', 'Volvo', 'Alfa Romeo',
#        'Harley-Davidson', 'MAN', 'Kayo', 'Li Auto', 'Kawasaki', 'ATV',
#        'GAC', 'Lynk & Co', 'Zontes', 'MG', 'GWM', 'Haval', 'Jetour',
#        'VGV', 'ZIL', 'Peugeot', 'Bestune', 'Mack', 'Wuling', 'XPeng',
#        'ROX ', 'ZAZ', 'Yamaha', 'Minsk', 'Suzuki', 'DongFeng', 'Voyah',
# ...

# %%
df.groupby(['Marka'])['Price'].mean()
# Out:
# Marka
# ATV             3508.333333
# Abarth         18134.311927
# Acura          18979.090909
# Alfa Romeo    112107.023555
# Aprilia        17914.191919
#                   ...
# ZXMCO           2625.000000
# Zamyad         38700.000000
# Zongshen        4733.166667
# Zontes          3828.571429
# iCar           42330.000000
# Name: Price, Length: 208, dtype: float64

# %%
df['Vəziyyəti'].isna().sum()
# Out:
# 3

# %%
# df['day'] = pd.to_datetime(df['day'], format='%d.%m.%Y')

# %%
# df['day'].dtype

# %%
# df['hour'] = pd.to_datetime(df['hour'], format='%H:%M')

# %%
X=df.drop('Price',axis=1)
y=df['Price'].copy()

# %%
y
# Out:
# 0          15000
# 1          23700
# 2          60520
# 3          26700
# 4          10500
#            ...
# 653716     10800
# 653717      9500
# 653718     25400
# 653719     10600
# 653720    218450
# Name: Price, Length: 653721, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=13)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler,OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error

# %%
num_feature=X_train.select_dtypes(include=[np.number]).columns

# %%
cat_feature=X_train.select_dtypes(exclude=[np.number]).columns

# %%
num_feature
# Out:
# Index(['production_year', 'engine_displacement_num', 'kilometrage_num',
#        'Buraxılış ili', 'Sahiblər', 'Yerlərin sayı', 'Yürüş',
#        'Mühərrik_part2'],
#       dtype='object')

# %%
cat_feature
# Out:
# Index(['city', 'day', 'hour', 'engine_displacement_unit', 'barter', 'loan',
#        'salon', 'spare_parts', 'vip', 'featured', 'shop_name', 'updated',
#        'vin', 'Ban növü', 'Hansı bazar üçün yığılıb', 'Marka', 'Model',
#        'Qəzalı', 'Rəng', 'Sürətlər qutusu', 'Vəziyyəti', 'Yeni', 'Ötürücü',
#        'Mühərrik_part3'],
#       dtype='object')

# %%
df
# Out:
#          Price      city         day   hour  production_year  \
# 0        15000      bakı  13.09.2024  23:28             2008
# 1        23700      bakı  13.09.2024  23:59             2024
# 2        60520      bakı  13.09.2024  23:59             2011
# 3        26700      bakı  13.09.2024  23:59             2018
# 4        10500      bakı  13.09.2024  23:59             2007
# ...        ...       ...         ...    ...              ...
# 653716   10800      bakı  05.01.2025  00:03             2008
# 653717    9500    göygöl  05.01.2025  00:32             2011
# 653718   25400      bakı  05.01.2025  00:00             2018
# 653719   10600  kürdəmir  05.01.2025  09:02             1999
# 653720  218450      bakı  05.01.2025  00:09             2023
#
#         engine_displacement_num engine_displacement_unit  kilometrage_num  \
# 0                           1.6                        L           270000
# 1                           1.7                        L                0
# ...

# %%
from sklearn.linear_model import Ridge
from sklearn.preprocessing import PolynomialFeatures

# %%
num_pipeline=Pipeline([
    ('impute',SimpleImputer(strategy='median')),
    ('encode',StandardScaler())
])

cat_pipeline=Pipeline([
    ('impute',SimpleImputer(strategy='constant',fill_value='missing')),
    ('encode', OneHotEncoder(handle_unknown='ignore',sparse_output=False))

])

transformer=ColumnTransformer([
    ('num',num_pipeline,num_feature),
    ('cat',cat_pipeline,cat_feature)
],remainder='passthrough')

estimator=Ridge()

full_pipeline=Pipeline([
    ('preprocessing',transformer),
    ('estimator',estimator)
])

# %%
full_pipeline.fit(X_train[:5000],y_train[:5000])
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num',
#                                                   Pipeline(steps=[('impute',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('encode',
#                                                                    StandardScaler())]),
#                                                   Index(['production_year', 'engine_displacement_num', 'kilometrage_num',
#        'Buraxılış ili', 'Sahiblər', 'Yerlərin sayı', 'Yürüş',
#        'Mühərrik_part2'],
#       dtype='object')),
#                                                  ('cat',
#                                                   Pipe...
#                                                                    OneHotEncoder(handle_unknown='ignore',
# ...

# %%
df.corr(numeric_only = True)['Price']
# Out:
# Price                      1.000000
# production_year           -0.046181
# engine_displacement_num    0.234955
# kilometrage_num           -0.330137
# Buraxılış ili              0.431003
# Sahiblər                  -0.154797
# Yerlərin sayı              0.098026
# Yürüş                     -0.370304
# Mühərrik_part2             0.613062
# Name: Price, dtype: float64

# %%
df['corr']=df['production_year']==df['Buraxılış ili']
df['corr'].value_counts()
# Out:
# corr
# True     647929
# False      5792
# Name: count, dtype: int64

# %%
df['vip'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='vip'>

# %%
df['production_year']
# Out:
# 0         2008
# 1         2024
# 2         2011
# 3         2018
# 4         2007
#           ...
# 653716    2008
# 653717    2011
# 653718    2018
# 653719    1999
# 653720    2023
# Name: production_year, Length: 653721, dtype: int64

# %%
df['Buraxılış ili']
# Out:
# 0         2008
# 1         2024
# 2         2011
# 3         2018
# 4         2007
#           ...
# 653716    2008
# 653717    2011
# 653718    2018
# 653719    1999
# 653720    2023
# Name: Buraxılış ili, Length: 653721, dtype: int64

# %%
full_pipeline.score(X_test,y_test)
# Out:
# 0.7255743436938329

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'estimator__alpha': [0.01, 0.1, 1, 10, 100]
}

grid_search = GridSearchCV(full_pipeline, param_grid, cv=5)

# %%
grid_search.fit(X_train[:5000],y_train[:5000])
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessing',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('num',
#                                                                          Pipeline(steps=[('impute',
#                                                                                           SimpleImputer(strategy='median')),
#                                                                                          ('encode',
#                                                                                           StandardScaler())]),
#                                                                          Index(['production_year', 'engine_displacement_num', 'kilometrage_num',
#        'Buraxılış ili', 'Sahiblər', 'Yerlərin sayı', 'Yürüş',
#        'Mühərrik_part2'],...
# ...

# %%
grid_search.best_params_
# Out:
# {'estimator__alpha': 1}

# %%
best_model=grid_search.best_estimator_

# %%
best_model.score(X_test,y_test)
# Out:
# 0.7255743436938329

# %%
best_model.score(X_train[:5000],y_train[:5000])
# Out:
# 0.9054924385983155

# %%
best_model.predict(X_test.iloc[:5])
# Out:
# array([110240.96193465,  10346.36987713,  22015.55984752, 226876.72498631,
#          -942.2575683 ])

# %%
y
# Out:
# 0          15000
# 1          23700
# 2          60520
# 3          26700
# 4          10500
#            ...
# 653716     10800
# 653717      9500
# 653718     25400
# 653719     10600
# 653720    218450
# Name: Price, Length: 653721, dtype: int64

# %%
y_test.iloc[:5]
# Out:
# 299386     11900
# 432082      7800
# 493629     30900
# 81895     211650
# 491809      9000
# Name: Price, dtype: int64

# %%
y_pred = full_pipeline.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
mse
# Out:
# 698660795.8972566

# %%
from sklearn.linear_model import Lasso
from sklearn.ensemble import StackingRegressor
from sklearn.ensemble import GradientBoostingRegressor,RandomForestRegressor
from sklearn.svm import SVR

# %%
base_learner=[
    ('rf',RandomForestRegressor()),
    ('gbr',GradientBoostingRegressor()),
    ('svr', SVR(kernel='rbf', C=1.0, epsilon=0.1))
]

meta_learner=RandomForestRegressor()

stacking_model = StackingRegressor(estimators=base_learner, final_estimator=meta_learner)

# %%
full_pipeline_stack = Pipeline([
    ('preprocessing', transformer),
    ('stacking', stacking_model)
])

# %%
full_pipeline_stack.fit(X_train[:5000],y_train[:5000])
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num',
#                                                   Pipeline(steps=[('impute',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('encode',
#                                                                    StandardScaler())]),
#                                                   Index(['production_year', 'engine_displacement_num', 'kilometrage_num',
#        'Buraxılış ili', 'Sahiblər', 'Yerlərin sayı', 'Yürüş',
#        'Mühərrik_part2'],
#       dtype='object')),
#                                                  ('cat',
#                                                   Pipe...
#        'salon', 'spare_parts', 'vip', 'featured', 'shop_name', 'updated',
# ...

# %%
full_pipeline_stack.score(X_test,y_test)
# Out:
# 0.8808749842487553
